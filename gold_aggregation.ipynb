# %%
dbutils.widgets.text(
    "silver_path",
    "/Volumes/workspace/ecommerce/ecommerce_data/silver/events"
)

dbutils.widgets.text(
    "gold_path",
    "/Volumes/workspace/ecommerce/ecommerce_data/gold/revenue_by_category"
)

silver_path = dbutils.widgets.get("silver_path")
gold_path = dbutils.widgets.get("gold_path")
