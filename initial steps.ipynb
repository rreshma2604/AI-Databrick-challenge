# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")
# Out:
# DataFrame[]

# %%
# %pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 130.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import os

os.environ["KAGGLE_USERNAME"] = "reshma26"
os.environ["KAGGLE_KEY"] = "29d52354c5e09d2a72c9aaa22560eed1"

print("Kaggle credentials configured!")

# !kaggle datasets download \
  -d mkechinov/ecommerce-behavior-data-from-multi-category-store \
  -p /Volumes/workspace/ecommerce/ecommerce_data
# Out:
# Kaggle credentials configured!
# Dataset URL: https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store
# License(s): copyright-authors
# ...
# 100%|█████████████████████████████████████▉| 4.28G/4.29G [01:11<00:00, 77.7MB/s]
# 100%|██████████████████████████████████████| 4.29G/4.29G [01:11<00:00, 64.0MB/s]

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
unzip -o ecommerce-behavior-data-from-multi-category-store.zip
ls -lh
# Out:
#   inflating: 2019-Nov.csv            total 6.6G
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 2.3G Jan  8 18:23 2019-Nov.csv
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 4.3G Jan  8 18:20 ecommerce-behavior-data-from-multi-category-store.zip
# Archive:  ecommerce-behavior-data-from-multi-category-store.zip
#   inflating: 2019-Nov.csv
#   inflating: 2019-Oct.csv
# total 18G
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 8.4G Jan  8 18:24 2019-Nov.csv
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 5.3G Jan  8 18:26 2019-Oct.csv
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 4.3G Jan  8 18:20 ecommerce-behavior-data-from-multi-category-store.zip

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
rm -f ecommerce-behavior-data-from-multi-category-store.zip
ls -lh
# Out:
# total 14G
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 8.4G Jan  8 18:24 2019-Nov.csv
# -rwxrwxrwx 1 spark-21aab960-a1df-4042-be17-22 nogroup 5.3G Jan  8 18:26 2019-Oct.csv

# %%
# %restart_python

# %%
df_n = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv")

# %%
df_oct = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# %%
print(f"October 2019 - Total Events: {df_oct.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df_oct.printSchema()
# Out:
# October 2019 - Total Events: 42,448,765
#
# ...
# SCHEMA:
# ...
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
display(df_oct.head(10))
# Out:
# ...
# SAMPLE DATA (First 5 rows):
# ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
